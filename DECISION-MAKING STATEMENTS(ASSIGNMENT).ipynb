# %%
#2. DECISION-MAKING STATEMENTS
#Use if, if-else, and if-elif-else wherever appropriate.
#Basic Decision-Making
#Check whether a number is positive or negative.
number=int(input("enter a number:"))
if (number>=0):
    print("positive")
else:
    print("negative")

#Check whether a number is even or odd.

number=int(input("enter a number:"))
if (number%2==0):
    print("even")
else:
    print("odd")

#Check whether a person is eligible to vote.

age=int(input("enter age:"))
if(age>=18):
    print("eligible for vote")
else:
    print("not eligible")
    
#Find the greater of two numbers.

number1=int(input("enter a number:"))
number2=int(input("enter a number:"))
if(number1>number2):
    print("greater")
else:
    print("lesser")
#Check whether a student has passed or failed. Passing marks are 40.

marks=int(input("enter marks:"))
if(marks>=40):
    print("pass")
else:
    print("fail")
#Check whether a number is divisible by 5.

number=int(input("enter a number:"))
if(number%5==0):
    print("divisible")
else:
    print("not found")
#Check whether a person is eligible for a driving license.

age=int(input("enter age:"))
if(age>=18):
    print("get driving license")
else:
    print("not eligible for driving")
    
#Display a grade based on the student's marks:
#80–100 → A
#60–79 → B
#40–59 → C
#Below 40 → Fail

marks=int(input("enter marks:"))
if(80<=marks<=100):
    print("grade A")
elif(60<=marks<80):
    print("grade B")
elif(40<=marks<60):
    print("grade C")
else:
    print("fail")

#Check whether a given year is a leap year.

year=int(input("enter a year:"))
if(year%4==0):
    print("leap year")
else:
    print("not leap year")
    
#Create a simple calculator using +, -, *, and /.

number1=float(input("enter a number:"))
operator=input("enter operator(+,-,*,/):")
number2=float(input("enter a number:"))
if operator=="+":
    print("add=",number1+number2)
elif operator=="-":
    print("sub=",number1-number2)
elif operator=="*":
    print("mult=",number1*number2)
elif operator=="/":
    print("div=",number1/number2)
else:
    print("invalid operator")
    
#Menu-Driven Questions
#Create a menu-driven program to perform the following operations:
#1 → Addition
#2 → Subtraction
#3 → Multiplication
#4 → Division
ch=int(input("enter choice"))
num1=float(input("enter a number:"))
num2=float(input("enter a number:"))
if ch==1:
    print("add:",num1+num2)
elif ch==2:
    print("sub:",num1-num2)
elif ch==3:
    print("mul:",num1*num2)
elif ch==4:
    print("div:",num1/num2)
else:
    print("not found")

#Create a menu-driven program for a student:
#1 → Display Student Name
#2 → Display Student Marks
#3 → Display Student Grade

ch=int(input("enter choice:"))
student_name=input("enter name")
marks=int(input("enter marks"))

if marks>=80 and marks<=100:
    grade="A"
elif marks>=60 and marks<=80:
    grade="B"
elif marks>=40 and marks <=60:
    grade="C"
else:
    grade="fail"
print("student_name",student_name)
print("marks",marks)
print("grade",grade)

#Create a menu-driven program for a basic banking system:
#1 → Check Balance
#2 → Deposit
#3 → Withdraw

ch==int(input("enter choice"))
account=25000
if ch==1:
    print("current_balance:",current_balance)
elif ch==2:
    amount=float(input("enter amount"))
    deposit=account+amount
    print("deposit:",deposit)
elif ch==3:
     withdraw=float(input("enter amount"))
     withdraw=account-withdraw
     print("withdraw",withdraw)
else:
    print("nothing")
    
#Create a menu-driven program to calculate:
#1 → Area of Rectangle
#2 → Area of Circle
#3 → Area of Square

ch=int(input("enter choice:"))
if ch==1:
   length=int(input("enter length:"))
   breath=int(input("enter breath:"))
   area_of_rectangle=length*breath
   print("area_of_rectangle",area_of_rectangle)
elif ch==2:
   radius=int(input("enter radius:"))
   area_of_circle=22/7*radius*radius
   print("area_of_circle",area_of_circle)
elif ch==3:
   side=int(input("enter side:"))
   area_of_square=side*side
   print("area_of_square",area_of_square)
else:
   print("not applicable")         

#Create a menu-driven program to convert:
#1 → Celsius to Fahrenheit
#2 → Fahrenheit to Celsius

ch=int(input("enter choice"))
if ch==1:
    celsius=float(input("enter celsius"))
    fahrenhein=(celsius*9/5)+32
    print("fahrenhein",fahrenhein)
elif ch==2:
    fahrenhein=float(input("enter fahrenhein"))
    celsius=(fahrenhein-32)*5/9
    print("celsius",celsius)
else:
    print("not found")
# Out:
# enter a number: -9
# negative
# enter a number: 90
# even
# enter age: 23
# eligible for vote
# enter a number: 32
# enter a number: 33
# lesser
# enter marks: 54
# pass
# enter a number: 45
# divisible
# enter age: 33
# get driving license
# enter marks: 41
# grade C
# enter a year: 2026
# not leap year
# enter a number: 21
# enter operator(+,-,*,/): -
# enter a number: 21
# sub= 0.0
# enter choice 2
# enter a number: 21
# enter a number: 22
# sub: -1.0
# enter choice: 2
# enter name rani
# enter marks 43
# student_name rani
# marks 43
# grade C
# enter choice 2
# enter amount 1200
# deposit: 26200.0
# enter choice: 2
# enter radius: 12
# area_of_circle 452.57142857142856
# enter choice 2
# enter fahrenhein 45
# celsius 7.222222222222222
