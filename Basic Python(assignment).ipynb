# %%
#1. BASIC PYTHON

#Write a Python program to print "Hello, Python!".

print("Hello,Python!")

#Store your name, age, and city in variables and display them.

Name="Mamatha"
Age=28
City="Hyderabad"
print("Name is", Name, "Age is", Age ,"City is",City)

#Take two numbers from the user and display their sum.

number1=int(input("enter a number:"))
number2=int(input("enter a nunber:"))
sum=number1+number2
print(sum)

#Take two numbers and display their addition, subtraction, multiplication, and division.

A=50
B=25
print(A+B)
print(A-B)
print(A*B)
print(A/B)

#Write a program to calculate the area of a rectangle.

length=int(input("enter length:"))
breath=int(input("enter breath:"))
Area =length*breath
print(Area)

#Write a program to calculate the area of a circle.

radius=int(input("enter radius:"))
Area=22/7*radius*radius
print(Area)

#Write a program to convert Celsius into Fahrenheit.
Celsius_tempereture=30
Fahrenheit_tempereture=Celsius_tempereture*9/5+32
print("Tempereture_fahrenheit:",Fahrenheit_tempereture)


#Take a student's name and marks and display the details.

student_name=input("enter name:")
marks=int(input("enter marks:"))
print("student_name:",student_name,"marks:",marks)

#Write a program to calculate Simple Interest using Principal, Rate, and Time.

principle=int(input("enter principle:"))
rate=int(input("enter rate:"))
time=int(input("enter time:"))
Simple_Interest=principle*rate*time/100
print("Simple_Interest:",Simple_Interest)

#Write a program to swap the values of two variables.
first_number=int(input("enter a number:"))
second_number=int(input("enter a number:"))
print("before_swaping:")
print("first_number:",first_number)
print("second_number:",second_number)
first_number,second_number=second_number,first_number
print("after_swaping:")
print("first_number:",first_number)
print("second_number:",second_number)
# Out:
# Hello,Python!
# Name is Mamatha Age is 28 City is Hyderabad
# enter a number: 20
# enter a nunber: 25
# 45
# 75
# 25
# 1250
# 2.0
# enter length: 12
# enter breath: 10
# 120
# enter radius: 7
# 154.0
# Tempereture_fahrenheit: 86.0
# enter name: nehal
# enter marks: 65
# student_name: nehal marks: 65
# enter principle: 2000
# enter rate: 10
# enter time: 2
# Simple_Interest: 400.0
# enter a number: 25
# enter a number: 35
# before_swaping:
# first_number: 25
# second_number: 35
# after_swaping:
# first_number: 35
# second_number: 25
