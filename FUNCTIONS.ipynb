# %%
#8. FUNCTIONS
#A. Basic Functions
#Create a function that prints "Hello Python".
print("Hello Python")
#Create a function that accepts a name and prints a welcome message.
def welcome(name):
  print("welcome",name)
welcome("Mamatha")
#Create a function that accepts two numbers and returns their sum.
def sum(a,b):
    c=a+b
    return c

n1=int(input("enter n1 number:"))
n2=int(input("enter n2 number:"))
n=sum(n1,n2)
print(n)
#Create a function to calculate the square of a number.
def square(x):
    y=x*x
    return y

num=int(input("enter number:"))
result=square(num)
print("result",result)
#Create a function to check whether a number is even or odd.
def check(a):
    if a%2==0:
      return "even"
    else:
        return "odd"
x=int(input("enter x number:"))
y=check(x)
print(y)
#Create a function to find the greater of two numbers.
def greater(x,y):
    if x>y:
        return x
    else:
        return y
n1=int(input("enter n1 number:"))
n2=int(input("enter n2 number:"))
result=greater(n1,n2)
print("result:",result)
#Create a function to calculate the area of a rectangle.
def area(a,b):
    c=a*b
    return c

length=int(input("enter length value:"))
breath=int(input("enter breath value:"))
Area=area(length,breath)
print("Area of rectagle:",Area)
#Create a function to calculate the factorial of a number.
def fact(x):
    result=1
    for i in range(1,x+1):
       result=result*i
    return result

num=int(input("enter number:"))
factorial=fact(num)
print("factorial:",factorial)
    
    
#Create a function that accepts marks and returns Pass or Fail.
def fun(x):
   if marks>=40:
       return "pass"
   else:
       return "fail"
marks=int(input("enter marks:"))
result=fun(marks)
print("result:",result)
#Create a function that accepts marks and returns the student's grade.
def grade(a):
   if 80<=marks<=100:
       return "grade A"
   elif 60<=marks<=80:
       return "grade B"
   elif 40<=marks<=60:
       return "grade C"
   else:
       return "fail"
marks=int(input("enter marks:"))
result=grade(marks)
print("result:",result)
#B. Functions with Lists
#Create a function that accepts a list and returns its length.
def show(l):
    for i in range(0,len(l)):
        print(l[i])
sales=[200,230,330,320,400,500]
show(sales)
#Create a function that accepts a list and returns the sum of all elements.
def cal_sum(numbers_list):
    total=0
    for num in numbers_list:
        total=total+num
    return total
sales=[200,230,330,320,400,500]
print("total_sales:",cal_sum(sales))
#Create a function that accepts a list and returns the maximum value.
def find_max(numbers):
      return max(numbers)
    
sales=[200,230,330,320,400,500]
max_value=find_max(sales)
print("max_value:",max_value)
#Create a function that accepts a list of marks and returns the number of passed students.
def count(list):
    countp=0
    for mark in list:
       if mark >=40:
           countp=countp+1
    return countp
marks=[45,56,43,32,83,20,25,48,44,53]
passed_students=count(marks)
print("passed_students:",passed_students)
#Create a function that accepts a list of marks and returns the number of failed students.
def count(list):
    countf=0
    for mark in list:
       if mark <=40:
           countf=countf+1
    return countf
marks=[45,56,43,32,83,20,25,48,44,53]
failed_students=count(marks)
print("failed_students:",failed_students)
#Create a function that accepts a list and returns a new list containing only even numbers.
def even(numbers_list):
     even_list=[]
     for i in numbers_list:
         if i%2==0:
             even_list.append(i)
     return even_list
numbers=[67,88,64,34,39,78,90,67,54,59]
new_list=even(numbers)
print("new_list:",new_list)
   
#C. Functions with Dictionaries
#Create a function that accepts a student dictionary and displays the student's name and marks.
def showdic(student_marks):
     for i in student_marks.items():
         print(i)
student_marks={"sruthi":67,"sandhya":45,"sanjay":90,"surya":58}
showdic(student_marks)
    
#Create a function that accepts a dictionary of student marks and returns the highest marks.
def highest_marks(students):
    return max(students.values())
students={"sruthi":67,"sandhya":45,"sanjay":90,"surya":58}
result=highest_marks(students)
print("Highest_marks:",result)

#Create a function that accepts a dictionary of students and marks and returns the number of passed students.
def passed(students):
    countp=0
    for marks in students.values():
        if marks >=40:
            countp=countp+1
    return countp
students={"sruthi":67,"sandhya":45,"sanjay":90,"surya":58}
passed_students=passed(students)
print("passed_students:",passed_students)
#Create a function that accepts a product-price dictionary and returns the total price of all products.
def total(products):
    total=0
    for price in products.values():
        total=total+price
    return total
products={"laptop":20000,"mobile":12000,"watch":5000,"earphones":2000}
total_price=total(products)
print("total_price:",total_price)
# Out:
# Hello Python
# welcome Mamatha
# enter n1 number: 12
# enter n2 number: 12
# 24
# enter number: 5
# result 25
# enter x number: 12
# even
# enter n1 number: 12
# enter n2 number: 12
# result: 12
# enter length value: 12
# enter breath value: 10
# Area of rectagle: 120
# enter number: 54
# factorial: 230843697339241380472092742683027581083278564571807941132288000000000000
# enter marks: 65
# result: pass
# enter marks: 54
# result: grade C
# 200
# 230
# 330
# 320
# 400
# 500
# total_sales: 1980
# max_value: 500
# passed_students: 7
# failed_students: 3
# new_list: [88, 64, 34, 78, 90, 54]
# ('sruthi', 67)
# ('sandhya', 45)
# ('sanjay', 90)
# ('surya', 58)
# Highest_marks: 90
# passed_students: 4
# total_price: 39000
