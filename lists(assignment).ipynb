# %%
#4. LISTS
#Use the following list for Questions 1–10:
marks = [45, 67, 32, 89, 56, 28, 76, 91, 35, 62]
#Find the length of the list using len().
marks = [45, 67, 32, 89, 56, 28, 76, 91, 35, 62]
print(len(marks))
#Find the total marks using sum().
print(sum(marks))
#Find the highest marks using max().

print(max(marks))

#Find the lowest marks using min().

print(min(marks))

#Sort the marks in ascending order.

marks.sort()
print(marks)

#Sort the marks in descending order.

marks.sort(reverse=True)
print(marks)

#Count how many students scored more than 50.
count=0
for i in range(0,len(marks)):
  if (marks[i]>=50):
     count=count+1
print(count)

#Count how many students passed, assuming passing marks are 40.

countp=0
for i in range(0,len(marks)):
    if(marks[i]>=40):
        countp=countp+1
print("countp",countp)
#Count how many students failed, assuming passing marks are 40.

countf=0
for i in range(0,len(marks)):
    if(marks[i]<=40):
        countf=countf+1
print("countf",countf)
#Calculate the average marks of all students.
avg=sum(marks)/len(marks)
print("average marks",avg)

#Additional List Practice

#Create a list of 10 student names and display the first five students.
names=["arya","ajay","asha","adhya","banny","balu","nehal","rani","ravi","krish"]
print(names[0:5])
#Create a list of student marks and count how many students scored above 80.
marks=[25,44,82,90,89,55,62,24,51,87]
for i in range(0,len(marks)):
    if marks[i]>=80:
      print(marks[i])
#Create a list of marks and count how many students scored between 40 and 60.
marks=[25,44,82,90,89,55,62,24,51,87]
count=0
for i in range(0,len(marks)):
    if 40<=marks[i]<=60:
     count=count+1
print("no of students:",count)
#Given a list of marks, find the second-highest mark.
marks.sort(reverse=True)
print("highest_marks",marks[0])
print("second_highest_marks",marks[1])
#Given a list of numbers, count how many numbers are even and odd.
counte=0
counto=0
for i in range(0,len(marks)):
    if marks[i]%2==0:
        counte=counte+1
    else:
        counto=counto+1
print("even no:",counte)
print("odd no:",counto)
    

#Given a list of numbers, create a new list containing numbers greater than 50.

m2=[num for num in marks if num>=50]
print(m2)
        
#Given a list of numbers, create a new list containing only even numbers.
m2=[num for num in marks if num%2==0]
print(m2)
#Given a list of student marks, create two lists:
#pass_students
#fail_students
student_marks=[45,52,72,41,80,38,64,23,75,69]
pass_students=[num for num in marks if num>=40]
fail_students=[num for num in marks if num<=40]
print("pass_students:",pass_students)
print("fail_students:",fail_students)
#Given a list of product prices, calculate the total price using sum().
product_price=[200,430,480,380,600,550,400,320,300,250]
print(sum(product_price))
#Given a list of product prices, find the maximum, minimum, and average price.
print(max(product_price))
print(min(product_price))
avg=sum(product_price)/len(product_price)
print(avg)
# Out:
# 10
# 581
# 91
# 28
# [28, 32, 35, 45, 56, 62, 67, 76, 89, 91]
# [91, 89, 76, 67, 62, 56, 45, 35, 32, 28]
# 6
# countp 7
# countf 3
# average marks 58.1
# ['arya', 'ajay', 'asha', 'adhya', 'banny']
# 82
# 90
# 89
# 87
# no of students: 3
# highest_marks 90
# second_highest_marks 89
# even no: 5
# odd no: 5
# [90, 89, 87, 82, 62, 55, 51]
# [90, 82, 62, 44, 24]
# pass_students: [90, 89, 87, 82, 62, 55, 51, 44]
# fail_students: [25, 24]
# 3910
# 600
# 200
# 391.0
